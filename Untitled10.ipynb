# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
dywidendy = simple_get('https://www.stockwatch.pl/dywidendy/')

# %%
>>> html = BeautifulSoup(dywidendy, 'html.parser')

# %%
html
# Out:
# <!DOCTYPE html>
#
# <html id="thc" lang="pl-PL" xmlns="http://www.w3.org/1999/xhtml">
# <head><link href="//static2.stockwatch.pl/content/images/favicon.ico" rel="shortcus icon" type="images/ico"/>
# <link href="//static2.stockwatch.pl/content/images/icon.png" rel="apple-touch-icon-precomposed"/>
# <meta content="noindex, nofollow" name="Googlebot-News"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <link href="//static2.stockwatch.pl/content/css/main_v4.css?v202005202" media="screen" rel="stylesheet" runat="server" type="text/css">
# <meta content="1033471596" property="fb:admins"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script type="application/ld+json">
#     {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.stockwatch.pl",
#     "potentialAction": {
#     "@type": "SearchAction",
#     "target": "https://www.stockwatch.pl/wiadomosci?s={search_term_string}",
#     "query-input": "required name=search_term_string"
#     }
#     }
# </script>
# <script type="application/ld+json">
#     {
#     "@context": "http://schema.org",
#     "@type": "Organization",
#     "url": "https://www.stockwatch.pl",
#     "contactPoint": [{
#     "@type": "ContactPoint",
#     "telephone": "+48 500 322 429",
#     "contactType" : "sales"
#     },
#     {
#     "@type": "ContactPoint",
#     "telephone": "+48 692 455 377",
#     "contactType" : "sales"
#     }]
#     }
# </script>
# <script src="//static2.stockwatch.pl/content/js/jquery.main.libs.js?v20190917" type="text/javascript"></script>
# <script src="//static2.stockwatch.pl/content/js/jquery.stock.libs.js?v20190917" type="text/javascript"></script>
# <!-- ADSO -->
# <script src="//static2.stockwatch.pl/content/js/adso.init.js?v=1"></script>
# <!-- Kod tagu remarketingowego Google #S -->
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 1053649992;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
# </script>
# <noscript>
# <div style="display:inline;">
# <img alt="pixelg" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1053649992/?guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# </div>
# </noscript>
# <!-- Koniec kodu tagu remarketingowego Google #S -->
# <!-- Global site tag (gtag.js) - Google AdWords: 1053649992 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1053649992"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'AW-1053649992');
# </script>
# <!-- Facebook Pixel Code -->
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '460944070762119');
#   fbq('track', 'PageView');
# </script>
# <noscript><img alt="pixelfb" height="1" src="https://www.facebook.com/tr?id=460944070762119&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Hotjar Tracking Code for http://www.stockwatch.pl/ -->
# <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:347328,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# </script>
# <!-- Twitter universal website tag code -->
# <script>
# !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);
# },s.version='1.1',s.queue=[],u=t.createElement(n),u.async=!0,u.src='//static.ads-twitter.com/uwt.js',
# a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,'script');
# // Insert Twitter Pixel ID and Standard Event data below
# twq('init','o1exq');
# twq('track','PageView');
# </script>
# <!-- End Twitter universal website tag code -->
# <script src="//static2.stockwatch.pl/content/js/jquery.global.init.js?v=v20190917" type="text/javascript"></script>
# <meta content="Kalendarium, kwoty, wiadomości i komunikaty dotyczące wszystkich dywidend w jednym miejscu.
# " name="description"><meta content="summary_large_image" name="twitter:card"/><meta content="@StockWatchPL" name="twitter:site"/><meta content="www.stockwatch.pl" name="twitter:domain"/><meta content="https://static2.stockwatch.pl/content/images/social/GrafikaGlownaSW.jpg" name="twitter:image"/><meta content="Dywidendy 2020 - Lista wszystkich wypłat" name="og:title"/><meta content="Dywidendy 2020 - Lista wszystkich wypłat" name="twitter:title"/><meta content="https://static2.stockwatch.pl/content/images/social/GrafikaGlownaSW.jpg" name="og:image"/><meta content="Spółki dzięki którym zarobisz - aktualna lista wszystkich wypłat" name="og:description"/><meta content="Spółki dzięki którym zarobisz - aktualna lista wszystkich wypłat" name="twitter:description"/><title>
# 	Dywidendy 2020 r - Lista wszystkich wypłat
# </title></meta></link></meta></head>
# <body id="ctl00_htmlbody">
# <form action="/SearchResults.aspx" defaultbutton="sa" id="csesearchbox" name="csesearchbox">
# <div id="googleDiv" style="display: none">
# <input name="cx" type="hidden" value="006735205996413836178:n15lq17pe2g"/>
# <input name="cof" type="hidden" value="FORID:11"/>
# <input name="ie" type="hidden" value="UTF-8"/>
# <input id="googleQ" name="q" size="31" type="hidden"/>
# <input id="sa" name="sa" type="submit" value="Szukaj"/>
# </div>
# </form>
# <form action="/dywidendy/default.aspx" id="aspnetForm" method="post" name="aspnetForm">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# <script type="text/javascript">
# //<![CDATA[
#
# function swShowDialogMultipleLoginNotPermitted(msg){
#     title = "Problem z logowaniem";
#     $("#LGDlg").html(msg);
#     $("#LGDlg").dialog({
#         title: title,
#      bgiframe: true,
#      resizable: false,
#      height:180,
#         width: 420,
#      modal: true,
#      beforeclose: function() { $("#LGDlg").dialog('destroy'); },
#      closeOnEscape: true
#     });
# };
#
#
# function swRunAfterLogin(message){
#     if(message!='OK'){
#         //if(message.indexOf('[multiplelogin]')==0)
#         //    swShowDialogMultipleLoginNotPermitted(message.replace('[multiplelogin]',''));
#         swShowDialogMultipleLoginNotPermitted(message);
#
#         /*wykonac akcje pokazania komunikatu*/
#         //$('#MsgAfterLogin').html(message);
#         $('#ctl00_LoginPanel_LI_LoginInfo_SWLoginForm').fadeIn(300);
#         ctl00_LoginPanel_LI_LoginInfo_SWLoginForm_UserName
#
#     } else { document.location.href='/dywidendy/default.aspx'; };
#
#     return false;
# }//]]>
# </script>
# <script src="/ScriptResource.axd?d=mVznRe5Be8wqB0b2fNw2A0zkTW0hT6L9KE3dEsVcQEC6usGpU6wniBMqsR16rHIvjlDDJ5eiNfo7x1Zp7R6CbV-065bxKMF07uzS0FhRyteEH9kOyvQhZk9mTyBx28WQrW1fuC_nb4oFLuyKVRc9CTYb-Ov2k4in79jJRZbUlht5_u2-0&amp;t=3f4a792d" type="text/javascript"></script>
# <script type="text/javascript">
# //<![CDATA[
# Sys.Services._AuthenticationService.DefaultWebServicePath = '../Authentication_JSON_AppService.axd';
# //]]>
# </script>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="AE82C715"/>
# <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="..."/>
# <div id="topAdCont">
# <!-- ADV -->
# <div class="bannerReg bnr0a">
# <span class="bnrdsc">AD.bx ad0a</span>
# <div class="lukasz"><!-- ADSO -->
# <div style="width: 970px; margin: auto auto">
# <script type="text/javascript">adsrv.container('16')</script>
# </div>
# </div>
# </div>
# </div>
# <div id="topNavCont">
# <nav id="topmn">
# <div class="alt-home-btn">
# <a href="/" title="StockWatch.pl"></a>
# </div>
# <div class="alt-menu-btn">
# <a class="btn btn-fa" href="javascript:void(0);"><i class="fa fa-bars"></i><span> Menu</span></a>
# </div>
# <div class="alt-col-btn" style="display: none;">
# <a class="btn btn-fa" href="javascript:;" id="show-custom-rc"><i class="fa fa-sign-in"></i><span> Zaloguj</span></a>
# </div>
# <ul class="topnav">
# <li class="link-homepage"><a href="//www.stockwatch.pl" title="Strona główna"><i class="fa fa-home"></i></a></li>
# <li>
# <a href="javascript:void(0);">Informacje</a>
# <ul>
# <li><a href="https://www.stockwatch.pl/wiadomosci/najnowsze">Wiadomości</a></li>
# <li><a href="/wiadomosci/wywiady-z-przedstawicielami-spolek-gieldowych">Wywiady</a></li>
# <li><a href="/czat-inwestorow-gieldowych/">Czaty inwestorskie</a></li>
# <li><a href="//trading.stockwatch.pl" target="_blank">Publikacje ekspertów instytucji finansowych</a></li>
# <li><a href="/w-mediach/">Przegląd prasy</a></li>
# <li><a href="/komunikaty-spolek/wszystkie.aspx">Komunikaty spółek (ESPI i EBI)</a></li>
# <li><a href="/terminarz/">Terminarz raportów</a></li>
# <li><a href="//edu.stockwatch.pl/" target="_blank">Edukacja</a></li>
# </ul>
# </li>
# <li><a href="javascript:void(0);">Akcje</a>
# <ul>
# <li><a href="/ipo/">Analizy ofert pierwotnych IPO</a></li>
# <li><a href="/raporty/">Analizy raportów finansowych</a></li>
# <li><a href="/wiadomosci/analizyforum">Analizy techniczne redakcji</a></li>
# <li><a href="/dywidendy/">Dywidendy</a></li>
# <li><a href="/notowania/?mst=f">Notowania</a></li>
# <li><a href="/gpw/indeks/gpw,sklad.aspx">Spółki z GPW</a></li>
# <li><a href="/gpw/indeks/ncindex,sklad.aspx">Spółki z NewConnect</a></li>
# <li><a href="/prawa-poboru/">Prawa poboru</a></li>
# <li><a href="/inwestorzy/">Portfele inwestorów (TFI, OFE, Skarb Państwa)</a></li>
# <li><a href="/rekomendacje/">Rekomendacje maklerskie</a></li>
# <li><a href="/ranking-kapitalizacji/">Ranking kapitalizacji</a></li>
# <li><a href="/gpw/indeksy">Indeksy GPW</a></li>
# <li><a href="/gpw/sektory">Sektory GPW</a></li>
# </ul>
# </li>
# <li><a href="javascript:void(0);">Obligacje</a>
# <ul>
# <li><a href="/obligacje/notowania/sektor/korporacyjne">Notowania</a></li>
# <li><a href="/obligacje/nowe-emisje/">Nowe emisje</a></li>
# <li><a href="/obligacje/najblizsze-wykupy/">Wykupy</a></li>
# <li><a href="/obligacje/emitenci/">Emitenci</a></li>
# <li><a href="/obligacje/analizy">Analizy emitentów</a></li>
# <li><a href="/obligacje/skaner/">Skaner obligacji</a></li>
# <li><a href="/obligacje/emitenci/">Spółki z Catalyst</a></li>
# <li><a href="/obligacje/najwyzsza-rentownosc/">Ranking rentowności</a></li>
# <li><a href="/obligacje/">Serwis rynku Catalyst</a></li>
# <li><a href="/wiadomosci/obligacje">Wiadomości</a></li>
# </ul>
# </li>
# <li><a class="premium" href="javascript:void(0);">Premium</a>
# <ul>
# <li><a href="/raporty/">Analizy raportów finansowych</a></li>
# <li><a href="/ipo/">Analizy ofert pierwotnych IPO</a></li>
# <li><a href="/wiadomosci/premium">Artykuły i analizy Premium</a></li>
# <li><a href="/wyceny/">Ranking wycen akcji</a></li>
# <li><a href="/stocks/Skaner-Fundamentalny.aspx">Skaner fundamentalny rynku akcji</a></li>
# <li><a href="/stocks/Skaner-Fundamentalny,zaawansowany.aspx">Zaawansowany skaner fundamentalny rynku akcji</a></li>
# <li><a href="/analizy-techniczne/skaner-techniczny.aspx">Skaner techniczny rynku akcji</a></li>
# <li><a href="/obligacje/skaner/">Skaner obligacji z rynku Catalyst</a></li>
# <li><a href="/wiadomosci/abonamenty-premium-w-stockwatch-pl">Opis korzyści z posiadania abonamentu do strefy premium</a></li>
# </ul>
# </li>
# <li><a class="portfele" href="javascript:void(0);">Portfele</a>
# <ul class="portfele">
# <li><b>Cztery fazy rynku</b></li></ul></li></ul></nav></div></form></body></html>
# <li><a href="/wiadomosci/portfel-stockwatch-pl-cztery-fazy-rynku">Sprawdź co oferujemy w ramach portfela Cztery Fazy Rynku</a></li>
# <li><a href="profil/abonament-i-uslugi.aspx#portfel">Wykup dostęp do portfela</a></li>
# <li><b>Dla subskrybentów:</b></li>
# <li><a href="/portfele/cztery-fazy-rynku/">Wyniki i skład portfela</a></li>
# <li><a href="/forum/tematy-50_Portfel-cztery-fazy-rynku.aspx">Zamknięte forum dyskusyjne</a></li>
# <li><b>Portfel użytkowników 2020</b></li>
# <li><a href="/portfele/portfel-uzytkownikow-stockwatch-2020/">Wyniki i skład portfela</a></li>
# <li><a href="/forum/wpisy-10935_PORTFEL-konkursowy-STOCKWATCH-2020.aspx">Otwarte forum dyskusyjne</a></li>
#
#
# <li><a class="anal" href="javascript:void(0);">A. Techniczna</a>
# <ul>
# <li><a href="/wiadomosci/analizyforum">Analizy techniczne redakcji</a></li>
# <li><a href="/analizy-techniczne/">Analizy techniczne użytkowników</a></li>
# <li><a href="/analiza-techniczna/">Narzędzie do analizy technicznej akcji</a></li>
# <li><a href="/kryptowaluty/analiza-techniczna/">Narzędzie do analizy technicznej kryptowalut</a></li>
# <li><a href="/profil/moje-analizy.aspx">Twoje analizy</a></li>
# </ul>
# </li>
# <li><a href="javascript:void(0);">Profil</a>
# <ul class="subnav">
# <li><a href="/profil/podsumowanie.aspx">Podsumowanie</a></li>
# <li><a href="/profil/moje-analizy.aspx">Moje analizy</a></li>
# <li><a href="/profil/obserwowane-spolki.aspx">Obserwowane spółki</a></li>
# <li><a href="/profil/subskrypcje.aspx">Subskrypcje</a></li>
# <li><a href="/profil/abonament-i-uslugi.aspx">Abonament Premium</a></li>
# <li><a href="/profil/abonament-i-uslugi.aspx#portfel">Portfel CFR</a></li>
# <li><a href="/profil/moje-dane.aspx">Moje dane</a></li>
# <li><a href="/wiadomosci/abonamenty-premium-w-stockwatch-pl">Sprawdź co oferujemy w ramach abonamentu do strefy premium</a></li>
# <li><a href="/wiadomosci/portfel-stockwatch-pl-cztery-fazy-rynku">Sprawdź co oferujemy w ramach portfela Cztery Fazy Rynku</a></li>
# </ul>
# </li>
# <li><a href="javascript:void(0);">Dla firm</a>
# <ul class="subnav">
# <li><a href="/wiadomosci/uslugi-relacji-inwestorskich">Relacje inwestorskie</a></li>
# <li><a href="/wiadomosci/czat-inwestorski-z-przedstawicielem-spolki-gieldowej">Czat inwestorski</a></li>
# <li><a href="/wiadomosci/dostarczanie-danych-finansowych">Dostarczanie danych finansowych</a></li>
# <li><a href="/wiadomosci/raport-analityczny-stockwatch-pl">Raporty analityczne</a></li>
# <li><a href="/wiadomosci/badania-inwestorow">Badania ankietowe inwestorów</a></li>
# <li><a href="/wiadomosci/reklama-w-stockwatch-pl">Reklama na stronie</a></li>
# </ul>
# </li>
# <li><a href="/forum" title="Forum inwestorów">Forum</a></li>
#
#
# <div class="clr"></div>
# <script language="javascript">
#
#
#
#     $(function () {
#
#         var searchTerm = '';
#         var searchItemFocused = false;
#         function highlight(text, q) {
#             var regex = new RegExp("(" + escape(q) + ")", "gi");
#             return text.replace(regex, "<strong>$1</strong>");
#         }
#
#
#         $("#autocomplete-search")
#             .autocomplete({
#                 source: function (request, response) {
#
#                     searchTerm = request.term;
#                     searchItemFocused = false;
#
#
#                     $.getJSON("/AutoCompleteService.asmx/GetList",
#                         { prefixText: searchTerm, count: 20 },
#                         function (data, status, xhr) {
#                             response(data);
#                         });
#
#                 }
#                ,
#
#                 focus: function (event, ui) {
#                     $("#autocomplete-search").val(ui.item.Name);
#                     searchItemFocused = true;
#                     return false;
#                 },
#                 select: function(event, ui) {
#                     window.location = ui.item.Url;
#                     return false;
#                 },
#                 close: function (event, ui) {
#
#                     searchItemFocused = false;
#                 }
#             })
#             .autocomplete("instance")
#             ._renderItem = function (ul, item) {
#                 return $("<li>")
#                     .append('<a href="' + item.Url + '">' + highlight(item.Name, searchTerm) + '</a>')
#                     .appendTo(ul);
#
#
#             }
#
#
#         $('#autocomplete-search')
#             .keydown(function(e) {
#                 console.log($('#ui-id-1').is(':visible'))
#                 if ($('.ui-state-active').length == 0 && event.keyCode == 13) {
#                     event.preventDefault();
#
#                     return false;
#                 }
#
#                 if (event.keyCode == 13 && !searchItemFocused) {
#                     event.preventDefault();
#
#                     return false;
#
#                 }
#
#                 return true;
#             });
#
#
#     })
# </script>
# <div class="usr-srcx">
# <div id="bxsrc">
# <div class="transFormers">
# <input autocomplete="off" class="inp1" id="autocomplete-search" placeholder="Znajdź akcje lub obligacje" type="text" value=""/>
# <span class="src-src" onclick="return RedirectToSearch()"></span>
# <span class="src-clr">
# <svg fill="#ffffff" height="13" viewbox="0 0 13 13" width="13" xmlns="http://www.w3.org/2000/svg">
# <path d="M5.182 6.596l-3.889-3.889-.707-.707 1.414-1.414.707.707 3.889 3.889 3.889-3.889.707-.707 1.414 1.414-.707.707-3.889 3.889 3.889 3.889.707.707-1.414 1.414-.707-.707-3.889-3.889-3.889 3.889-.707.707-1.414-1.414.707-.707 3.889-3.889z"></path>
# </svg>
# </span>
# </div>
# <span class="src-trgs"></span>
# <div class="clr"></div>
# </div>
# </div>
#
# <div id="main">
# <div id="top">
# <div class="l" itemtype="https://schema.org/NewsMediaOrganization">
# <a d="header_logo" href="/" id="pagelogo" itemprop="url">
# </a>
# </div>
# <div class="c">
# <!-- ADV -->
# <div class="box0b" style="width: 750px;">
# <script>adsrv.container('8')</script>
# </div>
# <div class="bannerReg bnr0b">
# <span class="bnrdsc">AD.bx ad0b</span>
# </div>
# </div>
# <div class="clr"></div>
# </div>
# <div class="clr"></div>
# <div class="clr"></div>
# <div id="swBd">
# <div class="col_left">
# <div class="clr"></div>
# <div id="SWCnt">
# <div id="MsgAfterLogin"></div>
# <div id="useraboad"></div>
# <script>
#
#                     (function() {
#                         $.post('/async/UserAboAdAsync.aspx',
#                             function(resp) {
#                                 $('#useraboad').html(resp);
#
#                             });
#                     })();
#                 </script>
# <div id="userinvestad"></div>
# <script>
#
#                     (function() {
#                         $.post('/async/UserInvestAdAsync.aspx',
#                             function(resp) {
#                                 $('#userinvestad').html(resp);
#
#                             });
#                     })();
#                 </script>
# <script language="javascript" type="text/javascript">
#         var currPage = 0;
#
#         function reloadList(page) {
#             $.get('/async/dividendsview.aspx?pg=' + page,
#                 function (result) {
#                     $("#dividendsListing").html(result)
#                 });
#         }
#
#         function getNext() {
#             currPage = currPage + 1;
#
#             reloadList(currPage);
#         }
#
#         function getBack() {
#             currPage = currPage - 1
#             reloadList(currPage);
#         }
#
#         function getLast(page) {
#             currPage = page;
#             reloadList(currPage);
#         }
#
#         function getFirst() {
#             currPage = 0;
#             reloadList(currPage);
#         }
#
#         function filterDivs() {
#             $('#dividendsListing').html('<div class="ajax-ov"><img src="//static2.stockwatch.pl/content/images/ajax_load.gif" /></div>');
#
#
#
#             $.get('/async/dividendsview.aspx?year=' + $('#ctl00_Body_YearSelector').val() + '&s=&pp=' + $('#ctl00_Body_DataPP').is(':checked') + "&IndexTicker=" + $('#ctl00_Body_IndexSelector').val(),
#                 function (result) {
#                     $("#dividendsListing").html(result);
#                 });
#
#         }
#
#
#     </script>
# <div class="DividendsPage1" id="DocPage1">
# <div id="BreadCrumbs"><a href="/">StockWatch.pl</a> <span>»</span> <a href="/dywidendy/">Dywidendy</a></div>
# <h1 class="catLead">Dywidendy wszystkie</h1>
# <img alt="Dywidendy" border="0" class="dywPix" src="https://www.stockwatch.pl/wiadomosci/wp-content/uploads/2016/06/dywidenda.jpg" style="max-width: 95%" title="Dywidendy"/>
# <p>
# Dla wielu inwestorów <strong>dywidendy</strong> są podstawową przesłanką inwestowania w akcje. Dywidenda jest bowiem wypłatą z zysku rocznego spółki, przekazywaną w gotówce na rachunek inwestora. Stanowi więc namacalną korzyść z posiadania akcji, w przeciwieństwie do wirtualnej korzyści, jaką jest wzrost wartości poprzez wzrost kursu giełdowego.
# </p>
# <p>
# Spółek wypłacających regularnie dywidendę jest niewiele, jakaś część robi to nieregularnie. StockWatch.pl śledzi wszystkie komunikaty i wiadomości dotyczące dywidend i zbiera je na tej podstronie. Oprócz tego <b>informacje o dywidendach dostępne są na stronach poszczególnych spółek. Wystarczy kliknąć w nazwę spółki na poniższej liście lub znaleźć ją w wyszukiwarce dostępnej w prawym górnym rogu strony.</b>
# </p>
# <p>
# Aby skutecznie stosować strategię dywidendową, trzeba znać daty ustalenia prawa do dywidendy oraz sposób rozliczania akcji z Krajowym Depozytem Papierów Wartościowych. Warto też śledzić wielkość poszczególnych dywidend, aby określić czy aktualny kurs akcji jest wystarczająco atrakcyjny.
# </p>
# <div id="DocPageCont">
# <div class="cllf">
# <script src="//static2.stockwatch.pl/content/js/community.ascin.js"></script>
# <script> callAscin('100,2000', 'widgetList', 'https://www.stockwatch.pl/wiadomosci/widget-dywidendy'); </script>
# </div>
# <div class="clrg">
# <div class="MsgBox bbox">
# <div class="bxld"><strong>Dywidendy</strong> - komunikaty spółek</div>
# <script>
#         	function amClickedOnEvent(chartId, date, description, id, url,ticker) {
# 					    //alert(chartId + "|" + date + "|"+ description + "|"+ id + "|"+ url +"|");
#           var attr = id.split(';');
#           var url2 = "/Stocks/event-"+ attr[0] +".aspx?id="+attr[1]+"&ticker="+ticker+"&mod=1";
#
#           	$('<iframe frameborder="0" class="externalSite" id="externalSite" src="'+url2+'"></iframe>').dialog({
#           		title: 'Komunikat spółki',
#               width:800,
#               closeOnEscape: true,
#               height:480,
#               modal:true,
#               resizable:true,
#               draggable:true,
# 							open: function (){
# 								$('iframe.externalSite').height( $(this).height() );
# 								$('iframe.externalSite').width( $(this).width()+475 );
# 							}
#   					});
#         	}
# </script>
# <table border="0" cellpadding="0" cellspacing="0" class="cctabdt" id="msgTable">
# <thead>
# <th class="comp">Spółka</th>
# <th class="date">Data</th>
# <th>Tytuł</th>
# </thead>
# <tbody>
# <tr>
# <td class="l evPos">
# <a href="/gpw/neuca,komunikaty,dywidendy.aspx">NEUCA</a>
# </td>
# <td class="c evPos">
#                2020-05-08
#             </td>
# <td class="evPos">
# <a class="evLK" href="javascript:void(0);" onclick="amClickedOnEvent(1,'','','espi;20200508_204450_0000186637', '','NEUCA')">informacja o zasadach wypłaty dywidendy</a>
# </td>
# </tr>
# <tr>
# <td class="l evPos">
# <a href="/gpw/quercus,komunikaty,dywidendy.aspx">QUERCUS</a>
# </td>
# <td class="c evPos">
#                2020-05-08
#             </td>
# <td class="evPos">
# <a class="evLK" href="javascript:void(0);" onclick="amClickedOnEvent(1,'','','espi;20200508_174905_0000186603', '','QUERCUS')">rekomendacja w sprawie podziału zysku </a>
# </td>
# </tr>
# <tr>
# <td class="l evPos">
# <a href="/gpw/lentex,komunikaty,dywidendy.aspx">LENTEX</a>
# </td>
# <td class="c evPos">
#                2020-05-08
#             </td>
# <td class="evPos">
# <a class="evLK" href="javascript:void(0);" onclick="amClickedOnEvent(1,'','','espi;20200508_100317_0000186542', '','LENTEX')">pozytywna opinia RN dot. wniosku zarządu w sprawie podziału zysku</a>
# </td>
# </tr>
# <tr>
# <td class="l evPos">
# <a href="/gpw/intercars,komunikaty,dywidendy.aspx">INTERCARS</a>
# </td>
# <td class="c evPos">
#                2020-05-07
#             </td>
# <td class="evPos">
# <a class="evLK" href="javascript:void(0);" onclick="amClickedOnEvent(1,'','','espi;20200507_160052_0000186481', '','INTERCARS')">rekomendacja RN w sprawie podziału zysku </a>
# </td>
# </tr>
# <tr>
# <td class="l evPos">
# <a href="/gpw/interaolt,komunikaty,dywidendy.aspx">INTERAOLT</a>
# </td>
# <td class="c evPos">
#                2020-05-07
#             </td>
# <td class="evPos">
# <a class="evLK" href="javascript:void(0);" onclick="amClickedOnEvent(1,'','','espi;20200507_135411_0000186463', '','INTERAOLT')">wypłata dywidendy 0,7 eur/akcja</a>
# </td>
# </tr>
# <tr>
# <td class="l evPos">
# <a href="/gpw/geotrans,komunikaty,dywidendy.aspx">GEOTRANS</a>
# </td>
# <td class="c evPos">
#                2020-05-07
#             </td>
# <td class="evPos">
# <a class="evLK" href="javascript:void(0);" onclick="amClickedOnEvent(1,'','','espi;20200507_002416_0000186425', '','GEOTRANS')">rekomendacja zarządu w sprawie wypłaty dywidendy</a>
# </td>
# </tr>
# <tr>
# <td class="l evPos">
# <a href="/gpw/lotos,komunikaty,dywidendy.aspx">LOTOS</a>
# </td>
# <td class="c evPos">
#                2020-05-06
#             </td>
# <td class="evPos">
# <a class="evLK" href="javascript:void(0);" onclick="amClickedOnEvent(1,'','','espi;20200506_210659_0000186420', '','LOTOS')">rekomendacja zarządu w zakresie wypłaty dywidendy</a>
# </td>
# </tr>
# <tr>
# <td class="l evPos">
# <a href="/gpw/ulma,komunikaty,dywidendy.aspx">ULMA</a>
# </td>
# <td class="c evPos">
#                2020-05-06
#             </td>
# <td class="evPos">
# <a class="evLK" href="javascript:void(0);" onclick="amClickedOnEvent(1,'','','espi;20200506_130747_0000186374', '','ULMA')">wypłata dywidendy 2,6 zł/akcja</a>
# </td>
# </tr>
# </tbody>
# </table>
# <div class="subLdBtm">
# <a href="/komunikaty-spolek/wszystkie.aspx?c=13">Zobacz wszystkie komunikaty spółek »</a>
# </div>
# </div>
# </div>
# <div class="clr"></div>
# </div>
# <!-- Escape SWCnt -->
# </div>
# </div>
# <div id="DocPageBreak">
# </div>
# <div id="SWCnt2">
# <!-- Escape SWCnt -->
# <div class="DividendsPage2" id="DocPage2">
# <a name="calendartable"></a>
# <div class="catLead RepCal">Kalendarium dywidend</div>
# <a name="focus"></a>
# <div id="StNavG">
# <span class="StNavGSel">
# <a class="tabc" href="/dywidendy/default.aspx#focus">Wszystkie</a>
# <a class="tab" href="/dywidendy/default.aspx?s=proponowana#focus">Proponowana</a>
# <a class="tab" href="/dywidendy/default.aspx?s=uchwalona#focus">Uchwalona</a>
# <a class="tab" href="/dywidendy/default.aspx?s=wyplacona#focus">Wypłacona</a>
# </span>
# <div class="clr"></div>
# </div>
# <div class="innerTab">
# <div class="panel-box">
# <table border="0" cellpadding="0" cellspacing="1" id="ScRnTb1">
# <tr>
# <td class="blg">
#                     Lista:
#                 </td>
# <td>
# <select id="ctl00_Body_IndexSelector" name="ctl00$Body$IndexSelector" onchange="">
# <option value="Wszystkie">Wszystkie</option>
# <option value="GPW">GPW</option>
# <option value="WIG">WIG</option>
# <option value="WIG20">WIG20</option>
# <option value="WIG30">WIG30</option>
# <option value="MWIG40">MWIG40</option>
# <option value="SWIG80">SWIG80</option>
# <option value="NCIndex">NCIndex</option>
# <option value="WIG.GAMES">WIG.GAMES</option>
# <option value="WIG.MS-BAS">WIG.MS-BAS</option>
# <option value="WIG.MS-FIN">WIG.MS-FIN</option>
# <option value="WIG.MS-PET">WIG.MS-PET</option>
# <option value="WIG-BANKI">WIG-BANKI</option>
# <option value="WIG-BUDOW">WIG-BUDOW</option>
# <option value="WIG-CEE">WIG-CEE</option>
# <option value="WIG-CHEMIA">WIG-CHEMIA</option>
# <option value="WIG-DIV">WIG-DIV</option>
# <option value="WIG-ENERG">WIG-ENERG</option>
# <option value="WIG-ESG">WIG-ESG</option>
# <option value="WIG-GORNIC">WIG-GORNIC</option>
# <option value="WIG-INFO">WIG-INFO</option>
# <option value="WIG-LEKI">WIG-LEKI</option>
# <option value="WIG-MEDIA">WIG-MEDIA</option>
# <option value="WIG-MOTO">WIG-MOTO</option>
# <option value="WIG-NRCHOM">WIG-NRCHOM</option>
# <option value="WIG-ODZIEZ">WIG-ODZIEZ</option>
# <option value="WIG-PALIWA">WIG-PALIWA</option>
# <option value="WIG-POLAND">WIG-POLAND</option>
# <option value="WIG-SPOZYW">WIG-SPOZYW</option>
# <option value="WIGTECH">WIGTECH</option>
# <option value="WIG-TELKOM">WIG-TELKOM</option>
# <option value="WIG-UKRAIN">WIG-UKRAIN</option>
# </select>
# </td>
# <td class="blg">
#                     Wybierz rok:
#                 </td>
# <td>
# <select id="ctl00_Body_YearSelector" name="ctl00$Body$YearSelector">
# <option value="2021">2021</option>
# <option value="2020">2020</option>
# <option selected="selected" value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# </select>
# </td>
# </tr>
# <tr>
# <td colspan="3">
# <p><input id="ctl00_Body_DataPP" name="ctl00$Body$DataPP" type="checkbox"/><label for="ctl00_Body_DataPP">uwzględnij wyłącznie termin ustalenia prawa do dywidendy</label></p>
# </td>
# <td class="r">
# <a class="btn btn-fa" href="javascript:void(0);" onclick="filterDivs(); return false;"><i class="fa fa-filter"></i> Filtruj wyniki</a>
# </td>
# </tr>
# </table>
# <div class="clr"></div>
# <div id="dividendsListing">
# <script type="text/javascript">
#  $(document).ready(function(){
#     $("#DividendsTab").tablesorter({
#     0: { sorter: "text" },
#     1: { sorter: "text" },
#     2: { sorter: "numeric" },
#     3: { sorter: "percent" },
#     4: { sorter: "date" },
#     5: { sorter: "date" },
#     6: { sorter: "text" },
#     7: { sorter: "date" }
#     });
#   })
# </script>
# <table cellpadding="0" cellspacing="0" class="cctabdt" id="DividendsTab">
# <thead>
# <tr>
# <th>Spółka</th>
# <th>Za okres</th>
# <th>Dyw. na akcje</th>
# <th>Stopa</th>
# <th>Ustalenie prawa</th>
# <th>Notowanie bez dyw.</th>
# <th>Stan wypłaty</th>
# <th>Data WZA</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="l"><strong><a href="/gpw/lotos,notowania,dywidendy.aspx">LOTOS</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">1,00</td>
# <td class="c">1,63%</td>
# <td class="c">2020-09-14</td>
# <td class="c">2020-09-11</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-09-28</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/passus,notowania,dywidendy.aspx">PASSUS</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,05</td>
# <td class="c">0,42%</td>
# <td class="c">2020-08-20</td>
# <td class="c">2020-08-19</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-11-19</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/odlewnie,notowania,dywidendy.aspx">ODLEWNIE</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,25</td>
# <td class="c">5,79%</td>
# <td class="c">2020-07-31</td>
# <td class="c">2020-07-30</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-08-21</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/izostal,notowania,dywidendy.aspx">IZOSTAL</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,11</td>
# <td class="c">4,15%</td>
# <td class="c">2020-07-24</td>
# <td class="c">2020-07-23</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-08-12</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/pknorlen,notowania,dywidendy.aspx">PKNORLEN</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">1,00</td>
# <td class="c">1,63%</td>
# <td class="c">2020-07-14</td>
# <td class="c">2020-07-13</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-07-28</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/ultgames,notowania,dywidendy.aspx">ULTGAMES</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,40</td>
# <td class="c">1,35%</td>
# <td class="c">2020-07-03</td>
# <td class="c">2020-07-02</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-07-17</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/pepees,notowania,dywidendy.aspx">PEPEES</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,12</td>
# <td class="c">7,14%</td>
# <td class="c">2020-07-01</td>
# <td class="c">2020-06-30</td>
# <td class="c">
#
#
#
#
# 	          uchwalona
#             <div class="stcm">2020-07-31</div>
# </td>
# <td class="c">2020-04-21</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/assecosee,notowania,dywidendy.aspx">ASSECOSEE</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,74</td>
# <td class="c">2,12%</td>
# <td class="c">2020-06-25</td>
# <td class="c">2020-06-24</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-07-08</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/mercator,notowania,dywidendy.aspx">MERCATOR</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,50</td>
# <td class="c">1,00%</td>
# <td class="c">2020-06-19</td>
# <td class="c">2020-06-18</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-06-26</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/domdev,notowania,dywidendy.aspx">DOMDEV</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">9,50</td>
# <td class="c">12,03%</td>
# <td class="c">2020-06-18</td>
# <td class="c">2020-06-17</td>
# <td class="c divComms" title="Komentarz|rekomendacja zawieszona">
# <span class="commentMarker">!</span>
#
#
# 	          proponowana
#             <div class="stcm">2020-06-25</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/dektra,notowania,dywidendy.aspx">DEKTRA</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,40</td>
# <td class="c">6,67%</td>
# <td class="c">2020-06-18</td>
# <td class="c">2020-06-17</td>
# <td class="c">
#
#
#
#
# 	          uchwalona
#             <div class="stcm">2020-07-02</div>
# </td>
# <td class="c">2020-05-06</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/unimot,notowania,dywidendy.aspx">UNIMOT</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">1,97</td>
# <td class="c">7,09%</td>
# <td class="c">2020-06-18</td>
# <td class="c">2020-06-17</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-07-09</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/lena,notowania,dywidendy.aspx">LENA</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,24</td>
# <td class="c">6,86%</td>
# <td class="c">2020-06-15</td>
# <td class="c">2020-06-12</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-06-29</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/decora,notowania,dywidendy.aspx">DECORA</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">1,00</td>
# <td class="c">5,56%</td>
# <td class="c">2020-06-10</td>
# <td class="c">2020-06-09</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-06-24</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/wawel,notowania,dywidendy.aspx">WAWEL</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">30,00</td>
# <td class="c">5,02%</td>
# <td class="c">2020-06-08</td>
# <td class="c">2020-06-05</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-06-16</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/assecopol,notowania,dywidendy.aspx">ASSECOPOL</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">3,01</td>
# <td class="c">4,13%</td>
# <td class="c">2020-06-05</td>
# <td class="c">2020-06-04</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-06-17</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/clnpharma,notowania,dywidendy.aspx">CLNPHARMA</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,08</td>
# <td class="c">0,25%</td>
# <td class="c">2020-06-02</td>
# <td class="c">2020-06-01</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-06-19</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/tsgames,notowania,dywidendy.aspx">TSGAMES</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">3,78</td>
# <td class="c">0,82%</td>
# <td class="c">2020-05-29</td>
# <td class="c">2020-05-28</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-06-10</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/ifirma,notowania,dywidendy.aspx">IFIRMA</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,03</td>
# <td class="c">0,88%</td>
# <td class="c">2020-05-29</td>
# <td class="c">2020-05-28</td>
# <td class="c divComms" title="Komentarz|zaliczka na poczet dywidendy">
# <span class="commentMarker">!</span>
#
#
# 	          uchwalona
#             <div class="stcm">2020-06-05</div>
# </td>
# <td class="c">2020-05-04</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/cpgroup,notowania,dywidendy.aspx">CPGROUP</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">2,10</td>
# <td class="c">22,48%</td>
# <td class="c">2020-05-26</td>
# <td class="c">2020-05-25</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-06-09</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/neuca,notowania,dywidendy.aspx">NEUCA</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">8,65</td>
# <td class="c">1,76%</td>
# <td class="c">2020-05-21</td>
# <td class="c">2020-05-20</td>
# <td class="c">
#
#
#
#
# 	          uchwalona
#             <div class="stcm">2020-05-28</div>
# </td>
# <td class="c">2020-05-06</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/asbis,notowania,dywidendy.aspx">ASBIS</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,32</td>
# <td class="c">8,42%</td>
# <td class="c">2020-05-21</td>
# <td class="c">2020-05-20</td>
# <td class="c divComms" title="Komentarz|0,075 USD/akcja">
# <span class="commentMarker">!</span>
#
#
# 	          uchwalona
#             <div class="stcm">2020-06-04</div>
# </td>
# <td class="c">2020-05-06</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/assecobs,notowania,dywidendy.aspx">ASSECOBS</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">1,80</td>
# <td class="c">4,97%</td>
# <td class="c">2020-05-19</td>
# <td class="c">2020-05-18</td>
# <td class="c">
#
#
#
#
# 	          uchwalona
#             <div class="stcm">2020-06-05</div>
# </td>
# <td class="c">2020-04-28</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/ulma,notowania,dywidendy.aspx">ULMA</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">2,60</td>
# <td class="c">5,05%</td>
# <td class="c">2020-05-18</td>
# <td class="c">2020-05-15</td>
# <td class="c">
#
#
#
#
# 	          uchwalona
#             <div class="stcm">2020-05-25</div>
# </td>
# <td class="c">2020-05-06</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/nwai,notowania,dywidendy.aspx">NWAI</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">1,00</td>
# <td class="c">13,70%</td>
# <td class="c">2020-05-15</td>
# <td class="c">2020-05-14</td>
# <td class="c">
#
#
#
#
# 	          uchwalona
#             <div class="stcm">2020-05-22</div>
# </td>
# <td class="c">2020-04-30</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/apsenergy,notowania,dywidendy.aspx">APSENERGY</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,05</td>
# <td class="c">3,60%</td>
# <td class="c">2020-05-15</td>
# <td class="c">2020-05-14</td>
# <td class="c">
#
#
#
#
# 	          uchwalona
#             <div class="stcm">2020-05-25</div>
# </td>
# <td class="c">2020-05-05</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/mbank,notowania,dywidendy.aspx">MBANK</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">1,15</td>
# <td class="c">0,58%</td>
# <td class="c">2020-05-14</td>
# <td class="c">2020-05-13</td>
# <td class="c divComms" title="Komentarz|nieprzyjęta">
# <span class="commentMarker">!</span>
#
#
# 	          proponowana
#             <div class="stcm">2020-05-28</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/interaolt,notowania,dywidendy.aspx">INTERAOLT</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">3,19</td>
# <td class="c">15,79%</td>
# <td class="c">2020-05-12</td>
# <td class="c">2020-05-11</td>
# <td class="c divComms" title="Komentarz|0,7 eur/akcja">
# <span class="commentMarker">!</span>
#
#
# 	          uchwalona
#             <div class="stcm">2020-05-18</div>
# </td>
# <td class="c">2020-04-27</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/play,notowania,dywidendy.aspx">PLAY</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">1,65</td>
# <td class="c">4,95%</td>
# <td class="c">2020-05-04</td>
# <td class="c">2020-05-01</td>
# <td class="c">
#
#
#
#
# 	          uchwalona
#             <div class="stcm">2020-05-12</div>
# </td>
# <td class="c">2020-04-14</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/krvitamin,notowania,dywidendy.aspx">KRVITAMIN</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,24</td>
# <td class="c">4,95%</td>
# <td class="c">2020-05-02</td>
# <td class="c">2020-04-30</td>
# <td class="c">
#
#
#
#
# 	          uchwalona
#             <div class="stcm">2020-05-14</div>
# </td>
# <td class="c">2020-04-27</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/xtb,notowania,dywidendy.aspx">XTB</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,24</td>
# <td class="c">2,17%</td>
# <td class="c">2020-04-30</td>
# <td class="c">2020-04-29</td>
# <td class="c">
#
#
#
#
# 	          uchwalona
#             <div class="stcm">2020-05-15</div>
# </td>
# <td class="c">2020-04-20</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/edinvest,notowania,dywidendy.aspx">EDINVEST</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,31</td>
# <td class="c">12,11%</td>
# <td class="c">2020-04-30</td>
# <td class="c">2020-04-29</td>
# <td class="c">
#
#
#
#
# 	          uchwalona
#             <div class="stcm">2020-05-15</div>
# </td>
# <td class="c">2020-04-23</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/kernel,notowania,dywidendy.aspx">KERNEL</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,96</td>
# <td class="c">2,20%</td>
# <td class="c">2020-04-23</td>
# <td class="c">2020-04-22</td>
# <td class="c divComms" title="Komentarz|0,25 USD/akcja">
# <span class="commentMarker">!</span>
#
#
# 	          wypłacona
#             <div class="stcm">2020-04-30</div>
# </td>
# <td class="c">2019-12-10</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/ingbsk,notowania,dywidendy.aspx">INGBSK</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">3,80</td>
# <td class="c">2,78%</td>
# <td class="c">2020-04-23</td>
# <td class="c">2020-04-22</td>
# <td class="c divComms" title="Komentarz|niepodjęta">
# <span class="commentMarker">!</span>
#
#
# 	          proponowana
#             <div class="stcm">2020-05-11</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/stalexp,notowania,dywidendy.aspx">STALEXP</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,05</td>
# <td class="c">2,01%</td>
# <td class="c">2020-04-10</td>
# <td class="c">2020-04-09</td>
# <td class="c">
#
#
#
#
# 	          proponowana
#             <div class="stcm">2020-04-22</div>
# </td>
# <td class="c"></td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/cda,notowania,dywidendy.aspx">CDA</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,70</td>
# <td class="c">1,90%</td>
# <td class="c">2020-03-30</td>
# <td class="c">2020-03-27</td>
# <td class="c">
#
#
#
#
# 	          wypłacona
#             <div class="stcm">2020-03-31</div>
# </td>
# <td class="c">2020-03-23</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/ifirma,notowania,dywidendy.aspx">IFIRMA</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,04</td>
# <td class="c">1,22%</td>
# <td class="c">2020-03-16</td>
# <td class="c">2020-03-13</td>
# <td class="c divComms" title="Komentarz|zaliczka na poczet dywidendy">
# <span class="commentMarker">!</span>
#
#
# 	          wypłacona
#             <div class="stcm">2020-03-23</div>
# </td>
# <td class="c">2020-02-21</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/atlantapl,notowania,dywidendy.aspx">ATLANTAPL</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,20</td>
# <td class="c">3,51%</td>
# <td class="c">2020-03-09</td>
# <td class="c">2020-03-06</td>
# <td class="c">
#
#
#
#
# 	          wypłacona
#             <div class="stcm">2020-03-27</div>
# </td>
# <td class="c">2019-12-17</td>
# </tr>
# <tr>
# <td class="l"><strong><a href="/gpw/livechat,notowania,dywidendy.aspx">LIVECHAT</a></strong></td>
# <td class="c range">od 2019-01-01<br/>do 2019-12-31</td>
# <td class="c">0,60</td>
# <td class="c">1,37%</td>
# <td class="c">2020-01-02</td>
# <td class="c">2020-01-01</td>
# <td class="c divComms" title="Komentarz|zaliczka na poczet dywidendy">
# <span class="commentMarker">!</span>
#
#
# 	          wypłacona
#             <div class="stcm">2020-01-09</div>
# </td>
# <td class="c">2019-12-02</td>
# </tr>
# <tr>
# ...
# <div class="subLdBtm"><a href="/czat-inwestorow-gieldowych/jacek-wyszynski-prezes-pyramid-game-chcemy-zadebiutowac-na-newconnect-w-czerwcu-lub-lipcu,313">Zobacz szczegóły</a> »</div>
# <div class="clr"></div>
# </li>
# <li class="roundAll">
# <a href="/czat-inwestorow-gieldowych/sebastian-reszpondek-prezes-zarzadu-ve-sa-ze-srodkow-pozyskanych-z-crowdfundingu-chcemy-zbudowac-nowe-urzadzenia-do-sprzedazy-globalnej,315" rel="nofollow"><img alt="Sebastian Reszpondek, prezes zarządu VE SA: Ze środków pozyskanych z crowdfundingu chcemy zbudować nowe urządzenia do sprzedaży globalnej" class="discGuest" src="https://www.stockwatch.pl/wiadomosci/wp-content/uploads/2020/04/sebastian-reszpondek-shield-bike.jpg" title="Sebastian Reszpondek, prezes zarządu VE SA: Ze środków pozyskanych z crowdfundingu chcemy zbudować nowe urządzenia do sprzedaży globalnej" width="80"/></a>
# <h2><a href="/czat-inwestorow-gieldowych/sebastian-reszpondek-prezes-zarzadu-ve-sa-ze-srodkow-pozyskanych-z-crowdfundingu-chcemy-zbudowac-nowe-urzadzenia-do-sprzedazy-globalnej,315">Sebastian Reszpondek, prezes zarządu VE SA: Ze środków pozyskanych z crowdfundingu chcemy zbudować nowe urządzenia do sprzedaży globalnej</a></h2>
# <div class="discStatus state state_archive">Spotkanie zakończone - <a href="/czat-inwestorow-gieldowych/sebastian-reszpondek-prezes-zarzadu-ve-sa-ze-srodkow-pozyskanych-z-crowdfundingu-chcemy-zbudowac-nowe-urzadzenia-do-sprzedazy-globalnej,315">Przeczytaj zapis czata</a></div>
# <div class="subLdBtm"><a href="/czat-inwestorow-gieldowych/sebastian-reszpondek-prezes-zarzadu-ve-sa-ze-srodkow-pozyskanych-z-crowdfundingu-chcemy-zbudowac-nowe-urzadzenia-do-sprzedazy-globalnej,315">Zobacz szczegóły</a> »</div>
# <div class="clr"></div>
# </li>
# <li class="roundAll">
# <a href="/czat-inwestorow-gieldowych/anna-strezynska-i-arkadiusz-szczebiot-zarzad-mc2-innovations-chcemy-zaistniec-globalnie-z-platforma-carrotspot,314" rel="nofollow"><img alt="Anna Streżyńska i Arkadiusz Szczebiot – zarząd MC2 Innovations: Chcemy zaistnieć globalnie z platformą Carrotspot" class="discGuest" src="https://www.stockwatch.pl/wiadomosci/wp-content/uploads/2020/04/mc2-innovations-strezynska-szczebiot.jpg" title="Anna Streżyńska i Arkadiusz Szczebiot – zarząd MC2 Innovations: Chcemy zaistnieć globalnie z platformą Carrotspot" width="80"/></a>
# <h2><a href="/czat-inwestorow-gieldowych/anna-strezynska-i-arkadiusz-szczebiot-zarzad-mc2-innovations-chcemy-zaistniec-globalnie-z-platforma-carrotspot,314">Anna Streżyńska i Arkadiusz Szczebiot – zarząd MC2 Innovations: Chcemy zaistnieć globalnie z platformą Carrotspot</a></h2>
# <div class="discStatus state state_archive">Spotkanie zakończone - <a href="/czat-inwestorow-gieldowych/anna-strezynska-i-arkadiusz-szczebiot-zarzad-mc2-innovations-chcemy-zaistniec-globalnie-z-platforma-carrotspot,314">Przeczytaj zapis czata</a></div>
# <div class="subLdBtm"><a href="/czat-inwestorow-gieldowych/anna-strezynska-i-arkadiusz-szczebiot-zarzad-mc2-innovations-chcemy-zaistniec-globalnie-z-platforma-carrotspot,314">Zobacz szczegóły</a> »</div>
# <div class="clr"></div>
# </li>
# </ul></div>
# <div class="subLdBtm outer"><a href="/czat-inwestorow-gieldowych">Więcej czatów</a> »</div>
# </div>
# <div id="PromoRegion">
# <div class="svForumNews" id="FrNws">
# <div class="bxld"><a href="/forum/" title="Zobacz wszystkie">Forum dyskusyjne </a></div>
# <div class="box1">
# <div class="FItem">
# <div class="FTh">
# <div class="l"><a href="/gpw/elbudowa,notowania,wskazniki.aspx" title="Przejdź do strony spółki ELBUDOWA">ELBUDOWA</a></div><div class="r"><nobr><em><b>2,925 zł</b> (<strong class="stup">+39,62%</strong>)</em></nobr></div>
# <div class="clr"></div>
# </div>
# <strong>marcin_t:</strong>
# <a href="/forum/wpis-najnowszy-404462_ELBUDOWA.aspx#404462" title="Weź udział w dyskusji o spółce ELBUDOWA">Jest jeszcze możliwość zmiany upadłości z likwidacyjnej na układową.
# Może o to w dowolnym momencie zawnioskować syndyk, ... </a>»
#         </div>
# <div class="clr"></div>
# <div class="FItem">
# <div class="FTh">
# <div class="l"><a href="/gpw/jsw,notowania,wskazniki.aspx" title="Przejdź do strony spółki JSW">JSW</a></div><div class="r"><nobr><em><b>12,66 zł</b> (<strong class="stup">+1,00%</strong>)</em></nobr></div>
# <div class="clr"></div>
# </div>
# <strong>spice:</strong>
# <a href="/forum/wpis-najnowszy-404461_JSW.aspx#404461" title="Weź udział w dyskusji o spółce JSW">JSW ma w swojej strategii dlugoterminowej oficjalnie zapisane procentowe zwiekszenie wydobycia wegla koksujacego w stosu ... </a>»
#         </div>
# <div class="clr"></div>
# <div class="FItem">
# <div class="FTh">
# <div class="l"><a href="/gpw/eccgames,notowania,wskazniki.aspx" title="Przejdź do strony spółki ECCGAMES">ECCGAMES</a></div><div class="r"><nobr><em><b>2,725 zł</b> (<strong class="stdw">-30,13%</strong>)</em></nobr></div>
# <div class="clr"></div>
# </div>
# <strong>kholat:</strong>
# <a href="/forum/wpis-najnowszy-404460_ECCGAMES.aspx#404460" title="Weź udział w dyskusji o spółce ECCGAMES">@Oxygen21
#
# Wiesz kto był wydawcą gniota God's Trigger od One More Level? Sam Techland... ... </a>»
#         </div>
# <div class="clr"></div>
# <div class="FItem">
# <div class="FTh">
# <div class="l"><a href="/gpw/pknorlen,notowania,wskazniki.aspx" title="Przejdź do strony spółki PKNORLEN">PKNORLEN</a></div><div class="r"><nobr><em><b>62,82 zł</b> (<strong class="stup">+3,22%</strong>)</em></nobr></div>
# <div class="clr"></div>
# </div>
# <strong>masterbosman:</strong>
# <a href="/forum/wpis-najnowszy-404459_PKNORLEN.aspx#404459" title="Weź udział w dyskusji o spółce PKNORLEN">na te minus 4% mogły zbiec się dwa fakty: kiepskie wyniki (które były do przewidzenia, jednak może nie dla wszystkich i ... </a>»
#         </div>
# <div class="clr"></div>
# <div class="FItem FItem-Post">
# <div class="FTh">
# <strong><a href="/forum/wpis-najnowszy-404458_post.aspx#404458" title="Weź udział w dyskusji Gamedev dot.com(pl)  2020">
#
#               Gamedev dot.com(pl)  2020</a></strong>
# </div>
# <strong>anty_teresa:</strong>
# <a href="/forum/wpis-najnowszy-404458_post.aspx#404458" title="Weź udział w dyskusji Gamedev dot.com(pl)  2020">1. Tak z powodów które wymieniłeś
# 2. Nie, bo to merytorycznie niepoprawne
# 3. Przewidywanie przyszłości jest trudne i s ... </a>»
#         </div>
# <div class="clr"></div>
# <div class="subLdBtm">
# <a href="/forum/">Więcej dyskusji na forum</a> »
# 	    </div>
# </div>
# </div>
# <!-- ADV -->
# <div class="bannerReg bnr3c">
# <span class="bnrdsc">AD.bx ad3c</span>
# <div class="ADbox3c"><!-- ADSO -->
# <div class="widget3c" style="margin: 10px">
# <script>adsrv.container('12')</script>
# </div>
# </div>
# </div>
# <div id="bxRatingHP">
# <div class="bxld"><a href="/stocks/Skaner-Fundamentalny.aspx?safetyZone=all">Ratingi Stabilności Spółek</a></div>
# <div class="box1">
# <p>Ocena wypłacalności spółek giełdowych oparta o wskaźnik Altmana ® dla polskiego rynku. <a href="http://wiadomosci.stockwatch.pl/kompendium-wskaznika-altmana-i-ratingu-kredytowego-w-stockwatch-pl,ratingi-i-upadlosci-spolek-gieldowych,37570">Dowiedz się więcej »</a> </p>
# <div class="ratCont">
# <div class="ratA">
# <a href="/stocks/Skaner-Fundamentalny.aspx?safetyZone=safe" title="Zobacz listę spółek w strefie bezpiecznej">
# <em>strefa bezpieczna</em>
# <span>AAA AA A BBB</span><br/>
# <strong>277</strong>
# </a>
# </div>
# <div class="ratB">
# <a href="/stocks/Skaner-Fundamentalny.aspx?safetyZone=uncertain" title="Zobacz listę spółek w strefie niepewnej">
# <em>strefa niepewna</em>
# <span>BB B</span><br/>
# <strong>139</strong>
# </a>
# </div>
# <div class="ratC">
# <a href="/stocks/Skaner-Fundamentalny.aspx?safetyZone=danger" title="Zobacz listę spółek w strefie zagrożonej">
# <em>strefa zagrożona</em>
# <span>CCC D</span><br/>
# <strong>152</strong>
# </a>
# </div>
# <div class="clr"></div>
# </div>
# <div class="subLdBtm">
# <a href="/stocks/Skaner-Fundamentalny.aspx?safetyZone=all" title="Wyszukuj ciekawe spółki skanerem fundamentalnym">Wszystkie ratingi</a> »
# 	    </div>
# </div>
# </div>
# <div id="funScHP">
# <div class="bxld"><a href="/stocks/Skaner-Fundamentalny.aspx">Skaner Fundamentalny</a></div>
# <div class="box1">
# <p><strong>Przykłady wyszukiwania spółek:</strong></p>
# <ul>
# <li>Zadłużenie większe od 80% - znaleziono <strong>70</strong></li>
# <li>ROE większe od 30% - znaleziono <strong>26</strong></li>
# <li>Free float mniejszy od 20% - znaleziono <strong>133</strong></li>
# </ul>
# <p><small>Dane aktualne na 08.05.2020</small></p>
# <div class="subLdBtm" style="display: block;">
# <a href="/stocks/Skaner-Fundamentalny.aspx">Więcej kryteriów skanowania</a> »
# 		</div>
# </div>
# </div>
# </div>
# <div id="bxPricingHP">
# <div class="bxld"><a href="/dywidendy/">Najbliższe dywidendy</a></div>
# <div class="box1">
# <table border="0" cellpadding="0" cellspacing="0" class="cctabdt">
# <tr>
# <th class="l">Spółka</th>
# <th>Dzień wypłaty</th>
# <th>Kwota na akcję</th>
# <th class="r">Stopa</th>
# </tr>
# <tr>
# <td class="l">
# <a href="/gpw/play,notowania,dywidendy.aspx"><strong>PLAY</strong></a>
# </td>
# <td>2020-05-12</td>
# <td class="scr1"><b>1,65</b></td>
# <td class="scr2">4,95%</td>
# </tr>
# <tr>
# <td class="l">
# <a href="/gpw/krvitamin,notowania,dywidendy.aspx"><strong>KRVITAMIN</strong></a>
# </td>
# <td>2020-05-14</td>
# <td class="scr1"><b>0,24</b></td>
# <td class="scr2">4,95%</td>
# </tr>
# <tr>
# <td class="l">
# <a href="/gpw/xtb,notowania,dywidendy.aspx"><strong>XTB</strong></a>
# </td>
# <td>2020-05-15</td>
# <td class="scr1"><b>0,24</b></td>
# <td class="scr2">2,17%</td>
# </tr>
# <tr>
# <td class="l">
# <a href="/gpw/edinvest,notowania,dywidendy.aspx"><strong>EDINVEST</strong></a>
# </td>
# <td>2020-05-15</td>
# <td class="scr1"><b>0,31</b></td>
# <td class="scr2">12,11%</td>
# </tr>
# <tr>
# <td class="l">
# <a href="/gpw/interaolt,notowania,dywidendy.aspx"><strong>INTERAOLT</strong></a>
# </td>
# <td>2020-05-18</td>
# <td class="scr1"><b>3,19</b></td>
# <td class="scr2">15,79%</td>
# </tr>
# </table>
# <div class="subLdBtm" style="display: block;">
# <a href="/dywidendy/">Więcej dywidend</a> »
#     </div>
# </div>
# </div>
# <!-- ADV -->
# <div class="bannerReg bnr3d">
# <div class="ADbox3d"><!-- ADSO -->
# <div style="text-align: center; padding: 10px 5px">
# </div></div>
# </div>
# <!-- ColR END --->
# </div>
# <br clear="all"/>
# <br clear="all"/>
# <div id="srvPart"><strong>Współpraca</strong><hr/>
# <a href="https://inwestycje.aliorbank.pl/" rel="nofollow" target="_blank" title="Biuro Maklerskie Alior Bank"><img alt="Biuro Maklerskie Alior Bank" src="//static2.stockwatch.pl/content/images/partn/alior.png" title="Biuro Maklerskie Alior Bank"/></a>
# <a href="https://bossa.pl" rel="nofollow" target="_blank" title="Bossa"><img alt="Bossa" border="0" src="//static2.stockwatch.pl/content/images/partn/bossa.gif" title="Bossa"/></a>
# <a href="https://pl.tradingview.com" rel="nofollow" target="_blank" title="tradingview"><img alt="tradingview" border="0" src="//www.stockwatch.pl/wiadomosci/wp-content/uploads/2017/12/tradingview-logo.jpg" title="tradingview"/></a>
# <a href="https://www.payu.pl" rel="nofollow" target="_blank" title="PAYU"><img alt="PayU" border="0" src="//static2.stockwatch.pl/content/images/partn/payu.png" title="PAYU"/></a>
# <a href="https://szukam-inwestora.com/" rel="nofollow" target="_blank" title="Szukam-Inwestora.com"><img alt="Szukam-Inwestora.com" border="0" src="//static2.stockwatch.pl/content/images/partn/szukamin.gif" title="Szukam-Inwestora.com"/></a>
# <a href="https://capitalpr.pl" rel="dofollow" target="_blank"><img alt="Kampanie reklamowe - emisje akcji, obligacji, crowdfunding udziałowy" border="0" src="//static2.stockwatch.pl/content/images/partn/logo_capital.png" title="Kampanie reklamowe - emisje akcji, obligacji, crowdfunding udziałowy"/></a>
# </div>
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/pl_PL/sdk.js#xfbml=1&version=v2.7&appId=220310818007806";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <script>
# $(document).ready(function(){
#  var cURL = window.location.href;
#   console.log(cURL);
#   if ( cURL == 'https://www.stockwatch.pl/abonament/potwierdzenie-zakupu.aspx' ) {
#     fbq('track', 'InitiateCheckout');
#    } else if (
#      cURL == 'https://stockwatch.pl/abonament/potwierdzenie-zakupu.aspx' ) {
#        fbq('track', 'InitiateCheckout');
#    } else if (
#      cURL == 'https://www.stockwatch.pl/profil/rejestracja-zakonczona.aspx' ) {
#       fbq('track', 'CompleteRegistration');
#    }  else if (
#      cURL == 'https://www.stockwatch.pl/profil/rejestracja-zakonczona.aspx' ) {
#       fbq('track', 'CompleteRegistration');
#    }
#  });
# </script>
# <div class="clr"></div>
# </div>
# <div class="clr"></div>
# <div id="footer">
# <div class="l">
#     Copyright © 2008-2020 <a href="https://stockwatch.pl/" title="StockWatch.pl">StockWatch.pl</a>
# </div>
# <div class="r">
# <a href="/" title="Strona główna">Strona główna</a> |
# 		<a href="/serwis/informacje/" title="O serwisie">O serwisie</a> |
#     <a href="/serwis/regulamin/" title="Regulamin serwisu">Regulamin</a> |
#     <a href="/serwis/faq/" title="FAQ">FAQ</a> |
#     <a href="/serwis/zastrzezenia/" title="Zastrzeżenia prawne">Zastrzeżenia prawne</a> |
#     <a href="/serwis/ochrona/" style="font-weight: bold; color: #fff" title="Ochrona prywatności">Ochrona prywatności i polityka cookies</a> |
#     <a href="//wiadomosci.stockwatch.pl/uslugi-relacji-inwestorskich" title="Usługi relacji inwestorskich">Usługi relacji inwestorskich</a> |
#     <a href="/serwis/reklama/" title="Reklama">Reklama</a> |
#     <a href="/serwis/kontakt/" title="Kontakt">Kontakt</a>
# </div>
# <div class="clr"></div>
# </div>
# <script type="text/javascript">
# //<![CDATA[
# $('.ATPopup').cluetip({splitTitle: '|', width: 430});Sys.Application.initialize();
# //]]>
# </script>
# </div>
# <div id="LGOwin" style="display: none;">
# <strong>Wybrałeś opcję wylogowania się z serwisu.</strong>
# <p>Poniżej potwierdź lub anuluj swój wybór.</p>
# <a class="" href="javascript:void(0);" title="Tak, wyloguj mnie"><i class="fa fa-close"></i>Tak wyloguj mnie</a>
# <a class="" href="javascript:void(0);" title="Zmieniłem zdanie"><i class="fa fa-check"></i>Zmieniłem zdanie</a>
# </div>
# <script type="text/javascript">
#   $(".logoff").click(function(){
#     $("#LGOwin").dialog({
#       title: 'Wyloguj ze StockWatch.pl',
#       bgiframe: true,
#       resizable: false,
#       height:140,
#       width: 360,
#       modal: true,
#       beforeclose: function() { $("#LGOwin").dialog('destroy'); },
#       closeOnEscape: true
#     });
#   });
#   $(".logoffx").click(function(){ $("#LGOwin").dialog('close');  });
#   $(".logoffy").click(function(){ window.location.href="/profil/wyloguj.aspx"; });
# </script>
# <!-- GA -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-2583313-1', 'auto');
#   ga('set', 'anonymizeIp', true);
#   gtag('config', 'AW-1053649992');
# </script>
# <!-- LinkedIn -->
# <script type="text/javascript">_linkedin_partner_id = "1094857";window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || [];window._linkedin_data_partner_ids.push(_linkedin_partner_id);</script>
# <script type="text/javascript">(function(){var s = document.getElementsByTagName("script")[0];var b = document.createElement("script");b.type = "text/javascript";b.async = true;b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";s.parentNode.insertBefore(b, s);})();</script>
# <noscript>
# <img alt="pixLin" height="1" src="https://dc.ads.linkedin.com/collect/?pid=1094857&amp;fmt=gif" style="display:none;" width="1">
# </img></noscript>
# <div id="swAnnouncerModal"></div>
# <script> ga('send', 'pageview', {'dimension2':'anonymous' });</script>

# %%
for i, td in enumerate(html.select('td')):
        print(i, td.text)
# Out:
# 0
# NEUCA
#
# 1
#                2020-05-08
#
# 2
# informacja o zasadach wypłaty dywidendy
#
# 3
# QUERCUS
#
# 4
#                2020-05-08
#
# 5
# rekomendacja w sprawie podziału zysku
#
# 6
# LENTEX
#
# 7
#                2020-05-08
#
# 8
# pozytywna opinia RN dot. wniosku zarządu w sprawie podziału zysku
#
# 9
# INTERCARS
#
# 10
#                2020-05-07
#
# 11
# rekomendacja RN w sprawie podziału zysku
#
# 12
# INTERAOLT
#
# 13
#                2020-05-07
#
# 14
# wypłata dywidendy 0,7 eur/akcja
#
# 15
# GEOTRANS
#
# 16
#                2020-05-07
#
# 17
# rekomendacja zarządu w sprawie wypłaty dywidendy
#
# 18
# LOTOS
#
# 19
#                2020-05-06
#
# 20
# rekomendacja zarządu w zakresie wypłaty dywidendy
#
# 21
# ULMA
#
# 22
#                2020-05-06
#
# 23
# wypłata dywidendy 2,6 zł/akcja
#
# 24
#                     Lista:
#
# 25
#
# Wszystkie
# GPW
# WIG
# WIG20
# WIG30
# MWIG40
# SWIG80
# NCIndex
# WIG.GAMES
# WIG.MS-BAS
# WIG.MS-FIN
# WIG.MS-PET
# WIG-BANKI
# WIG-BUDOW
# WIG-CEE
# WIG-CHEMIA
# WIG-DIV
# WIG-ENERG
# WIG-ESG
# WIG-GORNIC
# WIG-INFO
# WIG-LEKI
# WIG-MEDIA
# WIG-MOTO
# WIG-NRCHOM
# WIG-ODZIEZ
# WIG-PALIWA
# WIG-POLAND
# WIG-SPOZYW
# WIGTECH
# WIG-TELKOM
# WIG-UKRAIN
#
#
# 26
#                     Wybierz rok:
#
# 27
#
# 2021
# 2020
# 2019
# 2018
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2008
# 2007
# 2006
# 2005
# 2004
# 2003
# 2002
# 2001
#
#
# 28
# uwzględnij wyłącznie termin ustalenia prawa do dywidendy
#
# 29
#  Filtruj wyniki
#
# 30 LOTOS
# 31 od 2019-01-01do 2019-12-31
# 32 1,00
# 33 1,63%
# 34 2020-09-14
# 35 2020-09-11
# 36
#
#
#
#
# 	          proponowana
#             2020-09-28
#
# 37
# 38 PASSUS
# 39 od 2019-01-01do 2019-12-31
# 40 0,05
# 41 0,42%
# 42 2020-08-20
# 43 2020-08-19
# 44
#
#
#
#
# 	          proponowana
#             2020-11-19
#
# 45
# 46 ODLEWNIE
# 47 od 2019-01-01do 2019-12-31
# 48 0,25
# 49 5,79%
# 50 2020-07-31
# 51 2020-07-30
# 52
#
#
#
#
# 	          proponowana
#             2020-08-21
#
# 53
# 54 IZOSTAL
# 55 od 2019-01-01do 2019-12-31
# 56 0,11
# 57 4,15%
# 58 2020-07-24
# 59 2020-07-23
# 60
#
#
#
#
# 	          proponowana
#             2020-08-12
#
# 61
# 62 PKNORLEN
# 63 od 2019-01-01do 2019-12-31
# 64 1,00
# 65 1,63%
# 66 2020-07-14
# 67 2020-07-13
# 68
#
#
#
#
# 	          proponowana
#             2020-07-28
#
# 69
# 70 ULTGAMES
# 71 od 2019-01-01do 2019-12-31
# 72 0,40
# 73 1,35%
# 74 2020-07-03
# 75 2020-07-02
# 76
#
#
#
#
# 	          proponowana
#             2020-07-17
#
# 77
# 78 PEPEES
# 79 od 2019-01-01do 2019-12-31
# 80 0,12
# 81 7,14%
# 82 2020-07-01
# 83 2020-06-30
# 84
#
#
#
#
# 	          uchwalona
#             2020-07-31
#
# 85 2020-04-21
# 86 ASSECOSEE
# 87 od 2019-01-01do 2019-12-31
# 88 0,74
# 89 2,12%
# 90 2020-06-25
# 91 2020-06-24
# 92
#
#
#
#
# 	          proponowana
#             2020-07-08
#
# 93
# 94 MERCATOR
# 95 od 2019-01-01do 2019-12-31
# 96 0,50
# 97 1,00%
# 98 2020-06-19
# 99 2020-06-18
# 100
#
#
#
#
# 	          proponowana
#             2020-06-26
#
# 101
# 102 DOMDEV
# 103 od 2019-01-01do 2019-12-31
# 104 9,50
# 105 12,03%
# 106 2020-06-18
# 107 2020-06-17
# 108
# !
#
#
# 	          proponowana
#             2020-06-25
#
# 109
# 110 DEKTRA
# 111 od 2019-01-01do 2019-12-31
# 112 0,40
# 113 6,67%
# 114 2020-06-18
# 115 2020-06-17
# 116
#
#
#
#
# 	          uchwalona
#             2020-07-02
#
# 117 2020-05-06
# 118 UNIMOT
# 119 od 2019-01-01do 2019-12-31
# 120 1,97
# 121 7,09%
# 122 2020-06-18
# 123 2020-06-17
# 124
#
#
#
#
# 	          proponowana
#             2020-07-09
#
# 125
# 126 LENA
# 127 od 2019-01-01do 2019-12-31
# 128 0,24
# 129 6,86%
# 130 2020-06-15
# 131 2020-06-12
# 132
#
#
#
#
# 	          proponowana
#             2020-06-29
#
# 133
# 134 DECORA
# 135 od 2019-01-01do 2019-12-31
# 136 1,00
# 137 5,56%
# 138 2020-06-10
# 139 2020-06-09
# 140
#
#
#
#
# 	          proponowana
#             2020-06-24
#
# 141
# 142 WAWEL
# 143 od 2019-01-01do 2019-12-31
# 144 30,00
# 145 5,02%
# 146 2020-06-08
# 147 2020-06-05
# 148
#
#
#
#
# 	          proponowana
#             2020-06-16
#
# 149
# 150 ASSECOPOL
# 151 od 2019-01-01do 2019-12-31
# 152 3,01
# 153 4,13%
# 154 2020-06-05
# 155 2020-06-04
# 156
#
#
#
#
# 	          proponowana
#             2020-06-17
#
# 157
# 158 CLNPHARMA
# 159 od 2019-01-01do 2019-12-31
# 160 0,08
# 161 0,25%
# 162 2020-06-02
# 163 2020-06-01
# 164
#
#
#
#
# 	          proponowana
#             2020-06-19
#
# 165
# 166 TSGAMES
# 167 od 2019-01-01do 2019-12-31
# 168 3,78
# 169 0,82%
# 170 2020-05-29
# 171 2020-05-28
# 172
#
#
#
#
# 	          proponowana
#             2020-06-10
#
# 173
# 174 IFIRMA
# 175 od 2019-01-01do 2019-12-31
# 176 0,03
# 177 0,88%
# 178 2020-05-29
# 179 2020-05-28
# 180
# !
#
#
# 	          uchwalona
#             2020-06-05
#
# 181 2020-05-04
# 182 CPGROUP
# 183 od 2019-01-01do 2019-12-31
# 184 2,10
# 185 22,48%
# 186 2020-05-26
# 187 2020-05-25
# 188
#
#
#
#
# 	          proponowana
#             2020-06-09
#
# 189
# 190 NEUCA
# 191 od 2019-01-01do 2019-12-31
# 192 8,65
# 193 1,76%
# 194 2020-05-21
# 195 2020-05-20
# 196
#
#
#
#
# 	          uchwalona
#             2020-05-28
#
# 197 2020-05-06
# 198 ASBIS
# 199 od 2019-01-01do 2019-12-31
# 200 0,32
# 201 8,42%
# 202 2020-05-21
# 203 2020-05-20
# 204
# !
#
#
# 	          uchwalona
#             2020-06-04
#
# 205 2020-05-06
# 206 ASSECOBS
# 207 od 2019-01-01do 2019-12-31
# 208 1,80
# 209 4,97%
# 210 2020-05-19
# 211 2020-05-18
# 212
#
#
#
#
# 	          uchwalona
#             2020-06-05
#
# 213 2020-04-28
# 214 ULMA
# 215 od 2019-01-01do 2019-12-31
# 216 2,60
# 217 5,05%
# 218 2020-05-18
# 219 2020-05-15
# 220
#
#
#
#
# 	          uchwalona
#             2020-05-25
#
# 221 2020-05-06
# 222 NWAI
# 223 od 2019-01-01do 2019-12-31
# 224 1,00
# 225 13,70%
# 226 2020-05-15
# 227 2020-05-14
# 228
#
#
#
#
# 	          uchwalona
#             2020-05-22
#
# 229 2020-04-30
# 230 APSENERGY
# 231 od 2019-01-01do 2019-12-31
# 232 0,05
# 233 3,60%
# 234 2020-05-15
# 235 2020-05-14
# 236
#
#
#
#
# 	          uchwalona
#             2020-05-25
#
# 237 2020-05-05
# 238 MBANK
# 239 od 2019-01-01do 2019-12-31
# 240 1,15
# 241 0,58%
# 242 2020-05-14
# 243 2020-05-13
# 244
# !
#
#
# 	          proponowana
#             2020-05-28
#
# 245
# 246 INTERAOLT
# 247 od 2019-01-01do 2019-12-31
# 248 3,19
# 249 15,79%
# 250 2020-05-12
# 251 2020-05-11
# 252
# !
#
#
# 	          uchwalona
#             2020-05-18
#
# 253 2020-04-27
# 254 PLAY
# 255 od 2019-01-01do 2019-12-31
# 256 1,65
# 257 4,95%
# 258 2020-05-04
# 259 2020-05-01
# 260
#
#
#
#
# 	          uchwalona
#             2020-05-12
#
# 261 2020-04-14
# 262 KRVITAMIN
# 263 od 2019-01-01do 2019-12-31
# 264 0,24
# 265 4,95%
# 266 2020-05-02
# 267 2020-04-30
# 268
#
#
#
#
# 	          uchwalona
#             2020-05-14
#
# 269 2020-04-27
# 270 XTB
# 271 od 2019-01-01do 2019-12-31
# 272 0,24
# 273 2,17%
# 274 2020-04-30
# 275 2020-04-29
# 276
#
#
#
#
# 	          uchwalona
#             2020-05-15
#
# 277 2020-04-20
# 278 EDINVEST
# 279 od 2019-01-01do 2019-12-31
# 280 0,31
# 281 12,11%
# 282 2020-04-30
# 283 2020-04-29
# 284
#
#
#
#
# 	          uchwalona
#             2020-05-15
#
# 285 2020-04-23
# 286 KERNEL
# 287 od 2019-01-01do 2019-12-31
# 288 0,96
# 289 2,20%
# 290 2020-04-23
# 291 2020-04-22
# 292
# !
#
#
# 	          wypłacona
#             2020-04-30
#
# 293 2019-12-10
# 294 INGBSK
# 295 od 2019-01-01do 2019-12-31
# 296 3,80
# 297 2,78%
# 298 2020-04-23
# 299 2020-04-22
# 300
# !
#
#
# 	          proponowana
#             2020-05-11
#
# 301
# 302 STALEXP
# 303 od 2019-01-01do 2019-12-31
# 304 0,05
# 305 2,01%
# 306 2020-04-10
# 307 2020-04-09
# 308
#
#
#
#
# 	          proponowana
#             2020-04-22
#
# 309
# 310 CDA
# 311 od 2019-01-01do 2019-12-31
# 312 0,70
# 313 1,90%
# 314 2020-03-30
# 315 2020-03-27
# 316
#
#
#
#
# 	          wypłacona
#             2020-03-31
#
# 317 2020-03-23
# 318 IFIRMA
# 319 od 2019-01-01do 2019-12-31
# 320 0,04
# 321 1,22%
# 322 2020-03-16
# 323 2020-03-13
# 324
# !
#
#
# 	          wypłacona
#             2020-03-23
#
# 325 2020-02-21
# 326 ATLANTAPL
# 327 od 2019-01-01do 2019-12-31
# 328 0,20
# 329 3,51%
# 330 2020-03-09
# 331 2020-03-06
# 332
#
#
#
#
# 	          wypłacona
#             2020-03-27
#
# 333 2019-12-17
# 334 LIVECHAT
# 335 od 2019-01-01do 2019-12-31
# 336 0,60
# 337 1,37%
# 338 2020-01-02
# 339 2020-01-01
# 340
# !
#
#
# 	          wypłacona
#             2020-01-09
#
# 341 2019-12-02
# 342 SOPHARMA
# 343 od 2019-01-01do 2019-12-31
# 344 0,11
# 345 1,02%
# 346 2019-12-23
# 347 2019-12-20
# 348
# !
#
#
# 	          wypłacona
#             2020-01-22
#
# 349 2019-12-13
# 350 MLPGROUP
# 351 od 2019-01-01do 2019-12-31
# 352 0,22
# 353 0,44%
# 354 2019-12-20
# 355 2019-12-19
# 356
# !
#
#
# 	          wypłacona
#             2019-12-27
#
# 357 2019-12-09
# 358 PROMISE
# 359 od 2019-01-01do 2019-12-31
# 360 0,20
# 361 6,76%
# 362 2019-12-16
# 363 2019-12-13
# 364
# !
#
#
# 	          wypłacona
#             2019-12-23
#
# 365 2019-11-15
# 366 TIM
# 367 od 2019-01-01do 2019-12-31
# 368 0,80
# 369 7,41%
# 370 2019-12-13
# 371 2019-12-12
# 372
# !
#
#
# 	          wypłacona
#             2019-12-20
#
# 373 2019-11-07
# 374 ZYWIEC
# 375 od 2019-01-01do 2019-12-31
# 376 15,00
# 377 2,94%
# 378 2019-12-10
# 379 2019-12-09
# 380
# !
#
#
# 	          wypłacona
#             2019-12-17
#
# 381 2019-10-28
# 382 IFIRMA
# 383 od 2019-01-01do 2019-12-31
# 384 0,04
# 385 1,19%
# 386 2019-12-09
# 387 2019-12-06
# 388
# !
#
#
# 	          wypłacona
#             2019-12-16
#
# 389 2019-11-18
# 390 ASBIS
# 391 od 2019-01-01do 2019-12-31
# 392 0,23
# 393 7,18%
# 394 2019-12-09
# 395 2019-12-06
# 396
# !
#
#
# 	          wypłacona
#             2019-12-19
#
# 397 2019-11-28
# 398 APATOR
# 399 od 2019-01-01do 2019-12-31
# 400 0,45
# 401 2,10%
# 402 2019-12-05
# 403 2019-12-04
# 404
# !
#
#
# 	          wypłacona
#             2019-12-12
#
# 405 2019-11-05
# 406 SKARBIEC
# 407 od 2019-01-01do 2019-12-31
# 408 0,50
# 409 2,82%
# 410 2019-11-22
# 411 2019-11-21
# 412
#
#
#
#
# 	          wypłacona
#             2019-12-06
#
# 413 2019-10-24
# 414 ARCHICOM
# 415 od 2019-01-01do 2019-12-31
# 416 0,64
# 417 4,18%
# 418 2019-10-30
# 419 2019-10-29
# 420
# !
#
#
# 	          wypłacona
#             2019-11-06
#
# 421 2019-09-23
# 422 SANTANDER
# 423 od 2019-01-01do 2019-12-31
# 424 0,44
# 425 2,59%
# 426 2019-10-30
# 427 2019-10-29
# 428
# !
#
#
# 	          wypłacona
#             2019-10-30
#
# 429 2019-09-24
# 430 ECHO
# 431 od 2019-01-01do 2019-12-31
# 432 0,50
# 433 10,42%
# 434 2019-10-14
# 435 2019-10-11
# 436
# !
#
#
# 	          wypłacona
#             2019-10-21
#
# 437 2019-09-11
# 438 IFIRMA
# 439 od 2019-01-01do 2019-12-31
# 440 0,04
# 441 1,23%
# 442 2019-09-23
# 443 2019-09-20
# 444
# !
#
#
# 	          proponowana
#             2019-09-30
#
# 445
# 446 IMCOMPANY
# 447 od 2019-01-01do 2019-12-31
# 448 1,96
# 449 10,87%
# 450 2019-08-22
# 451 2019-08-21
# 452
# !
#
#
# 	          wypłacona
#             2019-08-29
#
# 453 2019-08-15
# 454 IFIRMA
# 455 od 2019-01-01do 2019-12-31
# 456 0,04
# 457 1,44%
# 458 2019-06-21
# 459 2019-06-19
# 460
# !
#
#
# 	          proponowana
#             2019-06-28
#
# 461
# 462 IMS
# 463 od 2019-01-01do 2019-12-31
# 464 0,20
# 465 8,26%
# 466
# 467
# 468
#
#
#
#
# 	          proponowana
#
#
# 469
# 470 APATOR
# 471 od 2019-01-01do 2019-12-31
# 472 0,85
# 473 4,47%
# 474
# 475
# 476
# !
#
#
# 	          proponowana
#
#
# 477
# 478 ARCTIC
# 479 od 2019-01-01do 2019-12-31
# 480 0,20
# 481 4,59%
# 482
# 483
# 484
# !
#
#
# 	          proponowana
#
#
# 485
# 486 ACAUTOGAZ
# 487 od 2019-01-01do 2019-12-31
# 488 2,80
# 489 7,31%
# 490
# 491
# 492
# !
#
#
# 	          proponowana
#
#
# 493
# 494 SIMPLE
# 495 od 2019-01-01do 2019-12-31
# 496 0,55
# 497 7,48%
# 498
# 499
# 500
#
#
#
#
# 	          proponowana
#
#
# 501
# 502 BETOMAX
# 503 od 2019-01-01do 2019-12-31
# 504 0,28
# 505 9,15%
# 506
# 507
# 508
#
#
#
#
# 	          proponowana
#
#
# 509 2020-03-09
# 510 AQUABB
# 511 od 2019-01-01do 2019-12-31
# 512 0,73
# 513 4,62%
# 514
# 515
# 516
#
#
#
#
# 	          proponowana
#
#
# 517
# 518 RAWLPLUG
# 519 od 2019-01-01do 2019-12-31
# 520 0,33
# 521 4,76%
# 522
# 523
# 524
#
#
#
#
# 	          proponowana
#
#
# 525
# 526 MAKARONPL
# 527 od 2019-01-01do 2019-12-31
# 528 0,25
# 529 4,59%
# 530
# 531
# 532
#
#
#
#
# 	          proponowana
#
#
# 533
# 534 KRKA
# 535 od 2019-01-01do 2019-12-31
# 536 19,28
# 537 5,60%
# 538
# 539
# 540
# !
#
#
# 	          proponowana
#
#
# 541
# 542 CEZ
# 543 od 2019-01-01do 2019-12-31
# 544 5,77
# 545 7,38%
# 546
# 547
# 548
# !
#
#
# 	          proponowana
#
#
# 549
# 550 GPW
# 551 od 2019-01-01do 2019-12-31
# 552 2,40
# 553 5,96%
# 554
# 555
# 556
#
#
#
#
# 	          proponowana
#
#
# 557
# 558 VINDEXUS
# 559 od 2019-01-01do 2019-12-31
# 560 0,10
# 561 2,11%
# 562
# 563
# 564
#
#
#
#
# 	          proponowana
#
#
# 565
# 566 FAMUR
# 567 od 2019-01-01do 2019-12-31
# 568 0,00
# 569 0,00%
# 570
# 571
# 572
#
#
#
#
# 	          proponowana
#
#
# 573
# 574 CASPAR
# 575 od 2019-01-01do 2019-12-31
# 576 1,74
# 577 5,69%
# 578
# 579
# 580
#
#
#
#
# 	          proponowana
#
#
# 581
# 582 LABOPRINT
# 583 od 2019-01-01do 2019-12-31
# 584 0,15
# 585 1,49%
# 586
# 587
# 588
#
#
#
#
# 	          proponowana
#
#
# 589
# 590 MENNICA
# 591 od 2019-01-01do 2019-12-31
# 592 0,50
# 593 2,66%
# 594
# 595
# 596
#
#
#
#
# 	          proponowana
#
#
# 597
# 598 MALKOWSKI
# 599 od 2019-01-01do 2019-12-31
# 600 0,08
# 601 9,76%
# 602
# 603
# 604
#
#
#
#
# 	          proponowana
#
#
# 605
# 606 KGL
# 607 od 2019-01-01do 2019-12-31
# 608 0,34
# 609 2,45%
# 610
# 611
# 612
#
#
#
#
# 	          proponowana
#
#
# 613
# 614 MOVIEGAMES
# 615 od 2019-01-01do 2019-12-31
# 616 0,32
# 617 0,49%
# 618
# 619
# 620
#
#
#
#
# 	          proponowana
#
#
# 621
# 622 APLISENS
# 623 od 2019-01-01do 2019-12-31
# 624 0,25
# 625 2,51%
# 626
# 627
# 628
#
#
#
#
# 	          proponowana
#
#
# 629
# 630 GEOTRANS
# 631 od 2019-01-01do 2019-12-31
# 632 0,80
# 633 3,62%
# 634
# 635
# 636
#
#
#
#
# 	          proponowana
#
#
# 637
# 638 01-01-2017
# 639
#  +105,39%
#
# 640
#      +21 078,22 zł
#
# 641 41 078,22 zł
# 642
#
#
# Logowanie
#
#
#
#
# Login:
#
#
#
# Hasło:
#
#
#
# ZALOGUJ
#
# Zaloguj
#
#
#
#
#
#
#
#                                     $(function () {
#
#                                         $('[action="log-in"]')
#                                             .click(function() {
#                                                 $('#ctl00_LoginPanel_LI_LoginInfo_SWLoginForm_LoginButton').trigger('click');
#
#                                             });
#
#                                         $('[action="remember-me"]')
#                                             .click(function () {
#
#                                                 var $this = $('[control=remember-me]');
#                                                 var v = $this.data('value');
#
#                                                 $this.removeClass('fa-check-square', 'fa-square');
#
#                                                 if (!v) {
#                                                     $this.addClass('fa-check-square');
#                                                 } else {
#                                                     $this.addClass('fa-square');
#                                                 }
#                                                 v = !v;
#                                                 $this.data('value', v);
#
#
#
#                                                 $('#ctl00_LoginPanel_LI_LoginInfo_SWLoginForm_RememberMe').attr("checked", v);
#
#
#                                             });
#                                     })
#
#
#
#
#
#
#  Zapamiętaj
#                                 |
#                                 Rejestruj
#                                 |
#                                 Aktywuj
#                                 |
#                                 Odzyskaj hasło
#
#
#
#
#
# 643
# Login:
#
#
# 644
# Hasło:
#
#
# 645
# ZALOGUJ
#
# Zaloguj
#
#
# 646
# PLAY
#
# 647 2020-05-12
# 648 1,65
# 649 4,95%
# 650
# KRVITAMIN
#
# 651 2020-05-14
# 652 0,24
# 653 4,95%
# 654
# XTB
#
# 655 2020-05-15
# 656 0,24
# 657 2,17%
# 658
# EDINVEST
#
# 659 2020-05-15
# 660 0,31
# 661 12,11%
# 662
# INTERAOLT
#
# 663 2020-05-18
# 664 3,19
# 665 15,79%
